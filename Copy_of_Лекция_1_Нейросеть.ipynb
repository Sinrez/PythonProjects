# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinrez/PythonProjects/blob/main/Copy_of_%D0%9B%D0%B5%D0%BA%D1%86%D0%B8%D1%8F_1_%D0%9D%D0%B5%D0%B9%D1%80%D0%BE%D1%81%D0%B5%D1%82%D1%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лекция №1. Генерация картинок

# %% [markdown]
# Привет! Сегодня мы сгенерируем вместе изображение с помощью модели с https://huggingface.co/.
#
# Если вы хотите хотите получить более подробное описание этой модели, необходимую информацию можно найти на странице модели: https://huggingface.co/dreamlike-art/dreamlike-photoreal-2.0

# %%
# !pip install diffusers
# !pip install transformers
# !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 2.2 MB/s eta 0:00:00
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "dreamlike-art/dreamlike-photoreal-2.0"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "photo, beautiful lake with old castle with cats with wings"
image = pipe(prompt).images[0]

image.save("./result.jpg")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from skimage import io

img = io.imread("result.jpg")
io.imshow(img)

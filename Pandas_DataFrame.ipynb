# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinrez/PythonProjects/blob/main/Pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
s1 = pd.Series(range(5))
s1.name = 'col1'
s1
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: col1, dtype: int64

# %%
s1 = pd.Series(['Ivan', 'Andrey', 'Igor'])
s1.name = 'users_name'

# %%
df = pd.DataFrame(s1)
df
# Out:
#   users_name
# 0       Ivan
# 1     Andrey
# 2       Igor

# %%
s = df['users_name']
print(s, type(s), s.dtype)
# Out:
# 0      Ivan
# 1    Andrey
# 2      Igor
# Name: users_name, dtype: object <class 'pandas.core.series.Series'> object

# %% [markdown]
# Повторяющиеся индексы

# %%
s = pd.Series([1,2,3], index = ['a', 'b', 'a'])
s['a']
# Out:
# a    1
# a    3
# dtype: int64

# %% [markdown]
# Заполнение DataFrame

# %%
data = {'city': ['Moscow', 'Moscow', 'Moscow', 'Kazan', 'Kazan', 'Kazan'],
        'year': [2022,2021,2020,2022,2021,2020],
        'visits': [500,2000,1500,100,230,200]}
data
# Out:
# {'city': ['Moscow', 'Moscow', 'Moscow', 'Kazan', 'Kazan', 'Kazan'],
#  'year': [2022, 2021, 2020, 2022, 2021, 2020],
#  'visits': [500, 2000, 1500, 100, 230, 200]}

# %%
df = pd.DataFrame(data)
df
# Out:
#      city  year  visits
# 0  Moscow  2022     500
# 1  Moscow  2021    2000
# 2  Moscow  2020    1500
# 3   Kazan  2022     100
# 4   Kazan  2021     230
# 5   Kazan  2020     200

# %%
df.head(2)
# Out:
#      city  year  visits
# 0  Moscow  2022     500
# 1  Moscow  2021    2000

# %%
df2 = pd.DataFrame(data, columns=['visits','city','year'])
df2
# Out:
#    visits    city  year
# 0     500  Moscow  2022
# 1    2000  Moscow  2021
# 2    1500  Moscow  2020
# 3     100   Kazan  2022
# 4     230   Kazan  2021
# 5     200   Kazan  2020

# %%
df2 = pd.DataFrame(data, columns=['visits','city','years'])
df2
# Out:
#    visits    city years
# 0     500  Moscow   NaN
# 1    2000  Moscow   NaN
# 2    1500  Moscow   NaN
# 3     100   Kazan   NaN
# 4     230   Kazan   NaN
# 5     200   Kazan   NaN

# %%
df3 = pd.DataFrame(data, columns=['visits','city','year'], index= ['a','b','c','d','e','f'])
df3
# Out:
#    visits    city  year
# a     500  Moscow  2022
# b    2000  Moscow  2021
# c    1500  Moscow  2020
# d     100   Kazan  2022
# e     230   Kazan  2021
# f     200   Kazan  2020

# %%
df3['city']
# Out:
# a    Moscow
# b    Moscow
# c    Moscow
# d     Kazan
# e     Kazan
# f     Kazan
# Name: city, dtype: object

# %%
df3.city
# Out:
# a    Moscow
# b    Moscow
# c    Moscow
# d     Kazan
# e     Kazan
# f     Kazan
# Name: city, dtype: object

# %% [markdown]
# Доступ к строкые (индексу)

# %%
print(df3.loc['a'], type(df3.loc['a']))
# Out:
# visits       500
# city      Moscow
# year        2022
# Name: a, dtype: object <class 'pandas.core.series.Series'>

# %% [markdown]
# Работа с колонками

# %%
df2['years'] = 0
df2
# Out:
#    visits    city  years
# 0     500  Moscow      0
# 1    2000  Moscow      0
# 2    1500  Moscow      0
# 3     100   Kazan      0
# 4     230   Kazan      0
# 5     200   Kazan      0

# %%
df2['new_column'] = range(100,106)
df2
# Out:
#    visits    city  years  new_column
# 0     500  Moscow      0         100
# 1    2000  Moscow      0         101
# 2    1500  Moscow      0         102
# 3     100   Kazan      0         103
# 4     230   Kazan      0         104
# 5     200   Kazan      0         105

# %%
df2['years'] = [1,2,3,4,5,6]
df2
# Out:
#    visits    city  years  new_column
# 0     500  Moscow      1         100
# 1    2000  Moscow      2         101
# 2    1500  Moscow      3         102
# 3     100   Kazan      4         103
# 4     230   Kazan      5         104
# 5     200   Kazan      6         105

# %%
df2['new_column'] = pd.Series([2022,2022], index = [0,3])
df2
# Out:
#    visits    city  years  new_column
# 0     500  Moscow      1      2022.0
# 1    2000  Moscow      2         NaN
# 2    1500  Moscow      3         NaN
# 3     100   Kazan      4      2022.0
# 4     230   Kazan      5         NaN
# 5     200   Kazan      6         NaN

# %%
data = {'user' : ['Ivan', 'Petr', 'Nikolay', 'Andrey'],
            'time_per_page' :  [10, 30 , 15, 5],
             'pages' : [7, 9, 12, 3]}
df = pd.DataFrame(data, index=['user1','user2','user3','user4'])
s1 = pd.Series([200,150], index=['user3','user4'])

def solution(df, s1):
    df['balance'] = pd.Series(s1, index=['user3','user4'])
    return df
df1 = solution(df,s1)
df1
# Out:
#           user  time_per_page  pages  balance
# user1     Ivan             10      7      NaN
# user2     Petr             30      9      NaN
# user3  Nikolay             15     12    200.0
# user4   Andrey              5      3    150.0

# %%
df1[df1['balance'].isnull()].index
# Out:
# Index(['user1', 'user2'], dtype='object')

# %%
df1['total_time'] = df['time_per_page'] * df['pages']
# df1['is_correct'] = df1[
df1['is_correct'] = df1['total_time'] < 100
df1
# Out:
#           user  time_per_page  pages  balance  total_time  is_correct
# user1     Ivan             10      7      NaN          70        True
# user2     Petr             30      9      NaN         270       False
# user3  Nikolay             15     12    200.0         180       False
# user4   Andrey              5      3    150.0          15        True

# %%
import pandas as pd

def solution(_df):
    return 'f' in _df.index

# %%
import pandas as pd

data = [['Ivan', 25, 4, 50, 1],

        ['Petr', 40, 9, 250, 8],

        ['Nikolay', 19, 12, 25, 1],

        ['Sergey', 33, 6, 115, 6],

        ['Andrey', 38, 2, 152, 4],

        ['Ilya', 20, 18, 15, 2],

        ['Igor', 19, 2, 10, 1]]

_df = pd.DataFrame(data, columns=['user_name', 'user_age', 'user_clicks', 'user_balance', 'user_history'], index=list('abcdefg'))
new_col = [d.replace(r'user_', '') for d in _df.columns]
_df.columns = new_col
_df
# Out:
#       name  age  clicks  balance  history
# a     Ivan   25       4       50        1
# b     Petr   40       9      250        8
# c  Nikolay   19      12       25        1
# d   Sergey   33       6      115        6
# e   Andrey   38       2      152        4
# f     Ilya   20      18       15        2
# g     Igor   19       2       10        1

# %%
import pandas as pd

def solution(_df):
    # ваш код здесь
    return _df[['name', 'balance']][-3:]

# %%
import pandas as pd
data = {'col1': [10,20,30,40], 'col2': [2,11,23,4], 'col3': [8,1,4,5]}

df1 = pd.DataFrame(data, index = ['a','b','c','d'])

df2 = df1.T

df1.add(df2, fill_value = 0)
# Out:
#          a     b     c  col1  col2  col3     d
# a      NaN   NaN   NaN  10.0   2.0   8.0   NaN
# b      NaN   NaN   NaN  20.0  11.0   1.0   NaN
# c      NaN   NaN   NaN  30.0  23.0   4.0   NaN
# col1  10.0  20.0  30.0   NaN   NaN   NaN  40.0
# col2   2.0  11.0  23.0   NaN   NaN   NaN   4.0
# col3   8.0   1.0   4.0   NaN   NaN   NaN   5.0
# d      NaN   NaN   NaN  40.0   4.0   5.0   NaN

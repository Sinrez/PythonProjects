# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinrez/PythonProjects/blob/main/%C2%A0Fin_val.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ставка дисконтирования (WACC)
E = 96000000
D = 24000000
V = 120000000
Re = 0.25
Rd = 0.06
T = 0.2
print(f'WACC= {round(E/V*Re + D/V*Rd*(1-T),2)}')
# Out:
# WACC= 0.21

# %%
pip install numpy_financial

# %%
import numpy_financial as npf

# Сценарий 1: Базовый (25 млн/год)
cash_flows1 = [-120_000_000, 0, 25_000_000, 25_000_000, 25_000_000, 25_000_000, 25_000_000]
irr1 = npf.irr(cash_flows1)
print(f"1. IRR при доходе 25 млн/год: {irr1:.2%}")

# Сценарий 2: Реалистичный (60 млн/год)
cash_flows2 = [-120_000_000, 0, 60_000_000, 60_000_000, 60_000_000, 60_000_000, 60_000_000]
irr2 = npf.irr(cash_flows2)
print(f"2. IRR при доходе 60 млн/год: {irr2:.2%}")

# Сценарий 3: Оптимистичный (80 млн/год)
cash_flows3 = [-120_000_000, 0, 80_000_000, 80_000_000, 80_000_000, 80_000_000, 80_000_000]
irr3 = npf.irr(cash_flows3)
print(f"3. IRR при доходе 80 млн/год: {irr3:.2%}")
# Out:
# 1. IRR при доходе 25 млн/год: 1.03%
# 2. IRR при доходе 60 млн/год: 27.60%
# 3. IRR при доходе 80 млн/год: 38.70%

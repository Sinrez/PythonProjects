# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinrez/PythonProjects/blob/main/comp_vis1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# !pip install matplotlib

# %%
import cv2
import matplotlib.pylab as plt

# %%
img = cv2.imread('/content/sample_data/10.jpg')
plt.imshow(img)
